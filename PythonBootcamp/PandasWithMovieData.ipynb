# %%
import pandas as pd

df = pd.read_csv('data/movies.csv')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df_sorted=df.sort_values(by=['votes'],ascending=False)
df_sorted
# Out:
#                           name rating   genre  year  \
# 5243           The Dark Knight  PG-13  Action  2008
# 2443  The Shawshank Redemption      R   Drama  1994
# 5643                 Inception  PG-13  Action  2010
# 2445              Forrest Gump  PG-13   Drama  1994
# 2444              Pulp Fiction      R   Crime  1994
# ...                        ...    ...     ...   ...
# 7660          Aloha Surf Hotel    NaN  Comedy  2020
# 7667                 Tee em el    NaN  Horror  2020
# 7661          Love by Drowning      R   Drama  2020
# 7662             The Robinsons    NaN  Action  2020
# 7666              It's Just Us    NaN   Drama  2020
#
#                                released  score      votes            director  \
# 5243      July 18, 2008 (United States)    9.0  2400000.0   Christopher Nolan
# 2443   October 14, 1994 (United States)    9.3  2400000.0      Frank Darabont
# 5643      July 16, 2010 (United States)    8.8  2100000.0   Christopher Nolan
# ...

# %%
df.year.max()   #looks like panda creates functions from the column names from the CSV!
# Out:
# np.int64(2020)

# %%
df.year.min()
# Out:
# np.int64(1980)

# %%
df_sorted.year.value_counts()
# Out:
# year
# 2008    200
# 1990    200
# 1997    200
# 2019    200
# 1992    200
# 2004    200
# 2016    200
# 2015    200
# 2018    200
# 2007    200
# 1988    200
# 2011    200
# 1989    200
# 1987    200
# 2017    200
# 1986    200
# 1996    200
# 1994    200
# 1985    200
# 2002    200
# 2010    200
# 2001    200
# 2003    200
# 2014    200
# 2012    200
# 1995    200
# 2013    200
# 2000    200
# 2009    200
# 2005    200
# 1998    200
# 1991    200
# 2006    200
# 1993    200
# 1999    200
# 1984    168
# 1983    144
# 1982    126
# 1981    113
# 1980     92
# 2020     25
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plot
import matplotlib
plot.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
pd.options.mode.chained_assignment = None

df_sorted.year.value_counts(normalize=True).plot.pie()

# df_sorted.genre.value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='proportion'>

# %%
import seaborn as sns
sns.regplot(x="budget", y = "gross",data=df_sorted,scatter_kws={"color":'purple'},line_kws={'color':'red'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
sns.lineplot(x="gross", y="budget", data=df,color="pink")
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='Blues')
plot.show()
